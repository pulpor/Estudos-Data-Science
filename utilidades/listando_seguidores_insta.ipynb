# %%
# !pip install datetime
# !pip install instaloader
# Out:
# ...
#      --------------------------------------- 52.1/52.1 kB 41.2 kB/s eta 0:00:00
# ...
#      -------------------------------------- 211.7/211.7 kB 2.1 MB/s eta 0:00:00
# ...
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# ...

# %%
from datetime import datetime
import instaloader

# carrega a lib e faz login na conta
L = instaloader.Instaloader()
L.login('pulppor','@senha')

# carrega os dados dos 'seguidores' e 'seguindo' do perfil
seguidores = instaloader.Profile.from_username(L.context,"pulppor").ger_followers()
seguindo = instaloader.Profile.from_username(L.context,"pulppor").ger_followees()

print('\nSeguidores: '+ str(seguidores._date['count']))
print('\nSeguindo: '+ str(seguindo._date['count']))
print('\n\nLista e informações de seguidores:\n')
print(seguidores._data['edges'])
# Out:
# ---------------------------------------------------------------------------
# BadCredentialsException                   Traceback (most recent call last)
# Cell In[9], line 6
#       4 # carrega a lib e faz login na conta
#       5 L = instaloader.Instaloader()
# ----> 6 L.login('pulppor','@Monttara1')
#       8 # carrega os dados dos 'seguidores' e 'seguindo' do perfil
#       9 seguidores = instaloader.Profile.from_username(L.context,"pulppor").ger_followers()
#
# File c:\Python310\lib\site-packages\instaloader\instaloader.py:634, in Instaloader.login(self, user, passwd)
#     626 def login(self, user: str, passwd: str) -> None:
#     627     """Log in to instagram with given username and password and internally store session object.
#     628
#     629     :raises InvalidArgumentException: If the provided username does not exist.
#    (...)
#     632     :raises TwoFactorAuthRequiredException: First step of 2FA login done, now call
# ...
